# %%
# load and inspect raw data
import pandas as pd

df = pd.read_csv("data/raw/cases.csv")

df = df.sample(frac=1, random_state=42).reset_index(drop=True)

df.shape
df.info()
df['label'].value_counts()

df.head(3) # civil = 0, criminal = 1, (legal_fees = 2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("data/raw/cases.csv")
#       5 df = df.sample(frac=1, random_state=42).reset_index(drop=True)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# data cleaning/preprocessing
from src.utils import clean_legal_text

from tqdm import tqdm

tqdm.pandas()


# call func
if 'text' in df.columns:
    df['cleaned_text'] = df.apply(lambda row: clean_legal_text(row['text'], row['label']), axis=1)

    # Save result
    df.to_csv("../data/interim/cases_cleaned.csv", index=False)
    print("Cleaning complete! Saved to cases_cleaned.csv")

    # Show samples
    for i in range(5):
        print(f"\nSample {i}:")
        print(df['cleaned_text'].iloc[i][:300])
        
df.shape
df.info()
df['label'].value_counts()

df.head(3)
